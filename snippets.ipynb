# %% [markdown]
# # Code snippets in Python
#
# Examples of common functionality
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bisentralen/python-for-students/blob/master/snippets.ipynb)

# %%
# Variables
a = 1.4
b = 2.2

# %%
# Maths
sum = a+b
d = ((2*a+b)**2)/5
print("sum =",sum)
print("d = ",d)
# Out:
# sum = 3.6
# d =  5.0
